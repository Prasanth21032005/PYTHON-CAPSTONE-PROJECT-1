# %%
# !pip install pandas
import pandas as pd
path = "dataset/HospInfo.csv"
df = pd.read_csv(path)
df.head()
# Out:
# ...
#    Provider ID                   Hospital Name                     Address  \
# 0        10005   MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH
# 1        10012  DEKALB REGIONAL MEDICAL CENTER        200 MED CENTER DRIVE
# 2        10032                WEDOWEE HOSPITAL       209 NORTH MAIN STREET
# 3        10095            HALE COUNTY HOSPITAL            508 GREEN STREET
# 4        10131        CRESTWOOD MEDICAL CENTER          ONE HOSPITAL DR SE
#
#          City State  ZIP Code County Name  Phone Number         Hospital Type  \
# 0        BOAZ    AL     35957    MARSHALL    2565938310  Acute Care Hospitals
# 1  FORT PAYNE    AL     35968     DE KALB    2568453150  Acute Care Hospitals
# 2     WEDOWEE    AL     36278    RANDOLPH    2563572111  Acute Care Hospitals
# 3  GREENSBORO    AL     36744        HALE    3346243024  Acute Care Hospitals
# 4  HUNTSVILLE    AL     35801     MADISON    2568823100  Acute Care Hospitals
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4812 entries, 0 to 4811
# Data columns (total 29 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Provider ID                                                    4812 non-null   int64
#  1   Hospital Name                                                  4812 non-null   object
#  2   Address                                                        4812 non-null   object
#  3   City                                                           4812 non-null   object
#  4   State                                                          4812 non-null   object
#  5   ZIP Code                                                       4812 non-null   int64
#  6   County Name                                                    4797 non-null   object
# ...

# %%
df.describe()
# Out:
#          Provider ID      ZIP Code  Phone Number
# count    4812.000000   4812.000000  4.812000e+03
# mean   268294.422901  53990.132377  5.848244e+09
# std    157109.340215  26915.916870  2.332196e+09
# min     10001.000000    603.000000  9.369338e+08
# 25%    140185.750000  33015.250000  4.014563e+09
# 50%    260043.500000  55410.500000  6.053360e+09
# 75%    390222.250000  76035.500000  7.877574e+09
# max    670118.000000  99929.000000  9.898943e+09

# %%
df.isnull()
# Out:
#       Provider ID  Hospital Name  Address   City  State  ZIP Code  \
# 0           False          False    False  False  False     False
# 1           False          False    False  False  False     False
# 2           False          False    False  False  False     False
# 3           False          False    False  False  False     False
# 4           False          False    False  False  False     False
# ...           ...            ...      ...    ...    ...       ...
# 4807        False          False    False  False  False     False
# 4808        False          False    False  False  False     False
# 4809        False          False    False  False  False     False
# 4810        False          False    False  False  False     False
# 4811        False          False    False  False  False     False
#
#       County Name  Phone Number  Hospital Type  Hospital Ownership  ...  \
# 0           False         False          False               False  ...
# ...

# %%
df.isnull().sum()
# Out:
# Provider ID                                                         0
# Hospital Name                                                       0
# Address                                                             0
# City                                                                0
# State                                                               0
# ZIP Code                                                            0
# County Name                                                        15
# Phone Number                                                        0
# Hospital Type                                                       0
# Hospital Ownership                                                  0
# Emergency Services                                                  0
# Meets criteria for meaningful use of EHRs                         144
# Hospital overall rating                                             0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Provider ID', 'Hospital Name', 'Address', 'City', 'State', 'ZIP Code',
#        'County Name', 'Phone Number', 'Hospital Type', 'Hospital Ownership',
#        'Emergency Services', 'Meets criteria for meaningful use of EHRs',
#        'Hospital overall rating', 'Hospital overall rating footnote',
#        'Mortality national comparison',
#        'Mortality national comparison footnote',
#        'Safety of care national comparison',
#        'Safety of care national comparison footnote',
#        'Readmission national comparison',
#        'Readmission national comparison footnote',
#        'Patient experience national comparison',
#        'Patient experience national comparison footnote',
#        'Effectiveness of care national comparison',
#        'Effectiveness of care national comparison footnote',
#        'Timeliness of care national comparison',
#        'Timeliness of care national comparison footnote',
# ...

# %%
df['Hospital Name'].unique()
df['City'].unique()
# Out:
# array(['BOAZ', 'FORT PAYNE', 'WEDOWEE', ..., 'PEARISBURG',
#        'POINT PLEASANT', 'ABINGDON'], shape=(2947,), dtype=object)

# %%
df.isnull().sum()
# Out:
# Provider ID                                                         0
# Hospital Name                                                       0
# Address                                                             0
# City                                                                0
# State                                                               0
# ZIP Code                                                            0
# County Name                                                        15
# Phone Number                                                        0
# Hospital Type                                                       0
# Hospital Ownership                                                  0
# Emergency Services                                                  0
# Meets criteria for meaningful use of EHRs                         144
# Hospital overall rating                                             0
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.select_dtypes(include='object').head()
# Out:
#                     Hospital Name                     Address        City  \
# 0   MARSHALL MEDICAL CENTER SOUTH  2505 U S HIGHWAY 431 NORTH        BOAZ
# 1  DEKALB REGIONAL MEDICAL CENTER        200 MED CENTER DRIVE  FORT PAYNE
# 2                WEDOWEE HOSPITAL       209 NORTH MAIN STREET     WEDOWEE
# 3            HALE COUNTY HOSPITAL            508 GREEN STREET  GREENSBORO
# 4        CRESTWOOD MEDICAL CENTER          ONE HOSPITAL DR SE  HUNTSVILLE
#
#   State County Name         Hospital Type  \
# 0    AL    MARSHALL  Acute Care Hospitals
# 1    AL     DE KALB  Acute Care Hospitals
# 2    AL    RANDOLPH  Acute Care Hospitals
# 3    AL        HALE  Acute Care Hospitals
# 4    AL     MADISON  Acute Care Hospitals
#
#                             Hospital Ownership  \
# 0  Government - Hospital District or Authority
# 1                                  Proprietary
# 2  Government - Hospital District or Authority
# 3                           Government - Local
# ...

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['Phone Number'] = df['Phone Number'].astype(str)
df['Phone Number'] = df['Phone Number'].where(
    df['Phone Number'].str.len() >= 10
)
df[['Hospital Name', 'Phone Number']].head()
# Out:
#                     Hospital Name Phone Number
# 0   MARSHALL MEDICAL CENTER SOUTH   2565938310
# 1  DEKALB REGIONAL MEDICAL CENTER   2568453150
# 2                WEDOWEE HOSPITAL   2563572111
# 3            HALE COUNTY HOSPITAL   3346243024
# 4        CRESTWOOD MEDICAL CENTER   2568823100

# %%
df['Phone Number'].isnull().sum()
df.groupby('City')['Phone Number'].apply(lambda x: x.notnull().sum())
# Out:
# City
# ABBEVILLE      2
# ABERDEEN       4
# ABILENE        3
# ABINGDON       1
# ABINGTON       1
#               ..
# ZANESVILLE     1
# ZEELAND        1
# ZEPHYRHILLS    1
# ZION           1
# ZUNI           1
# Name: Phone Number, Length: 2947, dtype: int64

# %%
'Bed Count' in df.columns
# Out:
# False

# %%
if 'Bed Count' not in df.columns:
    df['Bed Count'] = np.nan

df[['Bed Count']].head()
# Out:
#    Bed Count
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN

# %%
np.random.seed(42)
df['Bed Count'] = np.random.randint(20, 500, size=len(df))

df['Bed Count'].head()
# Out:
# 0    122
# 1    455
# 2    368
# 3    290
# 4    126
# Name: Bed Count, dtype: int32

# %%
df['Bed Count'].isnull().sum()
# Out:
# np.int64(0)

# %%
median_beds = df['Bed Count'].median()
median_beds
# Out:
# 261.0

# %%
df['Bed Count'] = df['Bed Count'].fillna(median_beds)

# %%
df['Bed Count'].isnull().sum()
# Out:
# np.int64(0)

# %%
def bed_category(beds):
    if beds < 50:
        return 'Small'
    elif beds <= 200:
        return 'Medium'
    else:
        return 'Large'

# %%
df['Bed Category'] = df['Bed Count'].apply(bed_category)

# %%
df[['Bed Count', 'Bed Category']].head()
# Out:
#    Bed Count Bed Category
# 0        122       Medium
# 1        455        Large
# 2        368        Large
# 3        290        Large
# 4        126       Medium

# %%
# !pip install pandas
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np

np.random.seed(0)
df['Bed Count'] = np.random.randint(20, 500, size=len(df))

# %%
df[['City', 'Bed Count']].head()
# Out:
#          City  Bed Count
# 0        BOAZ        192
# 1  FORT PAYNE         67
# 2     WEDOWEE        137
# 3  GREENSBORO        212
# 4  HUNTSVILLE        343

# %%
df['Bed Count'].dtype
# Out:
# dtype('int32')

# %%
df['Bed Count'] = pd.to_numeric(df['Bed Count'])

# %%
df.groupby('City')['Bed Count'].sum()
# Out:
# City
# ABBEVILLE       785
# ABERDEEN       1032
# ABILENE         882
# ABINGDON        277
# ABINGTON        458
#                ...
# ZANESVILLE      346
# ZEELAND         319
# ZEPHYRHILLS     203
# ZION            427
# ZUNI             39
# Name: Bed Count, Length: 2947, dtype: int32

# %%
df.groupby('City')['Bed Count'].mean()
# Out:
# City
# ABBEVILLE      392.5
# ABERDEEN       258.0
# ABILENE        294.0
# ABINGDON       277.0
# ABINGTON       458.0
#                ...
# ZANESVILLE     346.0
# ZEELAND        319.0
# ZEPHYRHILLS    203.0
# ZION           427.0
# ZUNI            39.0
# Name: Bed Count, Length: 2947, dtype: float64

# %%
df[['City', 'Hospital Name']].sort_values('City').head(20)
# Out:
#            City                                      Hospital Name
# 2288  ABBEVILLE                         ABBEVILLE GENERAL HOSPITAL
# 3484  ABBEVILLE                      ABBEVILLE AREA MEDICAL CENTER
# 2527   ABERDEEN             PIONEER COMMUNITY HOSPITAL OF ABERDEEN
# 3746   ABERDEEN                                     AVERA ST LUKES
# 4725   ABERDEEN                    GRAYS HARBOR COMMUNITY HOSPITAL
# 3303   ABERDEEN                    SANFORD ABERDEEN MEDICAL CENTER
# 1577    ABILENE                                  MEMORIAL HOSPITAL
# 4689    ABILENE                            HENDRICK MEDICAL CENTER
# 4694    ABILENE                    ABILENE REGIONAL MEDICAL CENTER
# 4811   ABINGDON                         JOHNSTON MEMORIAL HOSPITAL
# 3822   ABINGTON                         ABINGTON MEMORIAL HOSPITAL
# 2334   ACKERMAN                    CHOCTAW REGIONAL MEDICAL CENTER
# 2897        ADA                                ESSENTIA HEALTH ADA
# ...

# %%
city_kpi = df.groupby('City').agg(
    Total_Hospitals=('Hospital Name', 'count'),
    Total_Beds=('Bed Count', 'sum'),
    Average_Beds=('Bed Count', 'mean')
).reset_index()

city_kpi
# Out:
#              City  Total_Hospitals  Total_Beds  Average_Beds
# 0       ABBEVILLE                2         785         392.5
# 1        ABERDEEN                4        1032         258.0
# 2         ABILENE                3         882         294.0
# 3        ABINGDON                1         277         277.0
# 4        ABINGTON                1         458         458.0
# ...           ...              ...         ...           ...
# 2942   ZANESVILLE                1         346         346.0
# 2943      ZEELAND                1         319         319.0
# 2944  ZEPHYRHILLS                1         203         203.0
# 2945         ZION                1         427         427.0
# 2946         ZUNI                1          39          39.0
#
# [2947 rows x 4 columns]

# %%
city_kpi['Bed_to_Hospital_Ratio'] = (
    city_kpi['Total_Beds'] / city_kpi['Total_Hospitals']
)

city_kpi
# Out:
#              City  Total_Hospitals  Total_Beds  Average_Beds  \
# 0       ABBEVILLE                2         785         392.5
# 1        ABERDEEN                4        1032         258.0
# 2         ABILENE                3         882         294.0
# 3        ABINGDON                1         277         277.0
# 4        ABINGTON                1         458         458.0
# ...           ...              ...         ...           ...
# 2942   ZANESVILLE                1         346         346.0
# 2943      ZEELAND                1         319         319.0
# 2944  ZEPHYRHILLS                1         203         203.0
# 2945         ZION                1         427         427.0
# 2946         ZUNI                1          39          39.0
#
#       Bed_to_Hospital_Ratio
# 0                     392.5
# 1                     258.0
# 2                     294.0
# 3                     277.0
# 4                     458.0
# ...                     ...
# ...

# %%
df['Bed Count'].isnull().sum()
# Out:
# np.int64(0)

# %%
median_beds = df['Bed Count'].median()
median_beds
# Out:
# 260.5

# %%
df['Bed Count'] = df['Bed Count'].fillna(median_beds)

# %%
df['Bed Count'].isnull().sum()
# Out:
# np.int64(0)

# %%
df['Bed Count'].describe()
# Out:
# count    4812.000000
# mean      259.261014
# std       137.485679
# min        20.000000
# 25%       139.000000
# 50%       260.500000
# 75%       380.000000
# max       499.000000
# Name: Bed Count, dtype: float64

# %%
total_beds_city = df.groupby('City')['Bed Count'].sum()
total_beds_city.head()
# Out:
# City
# ABBEVILLE     785
# ABERDEEN     1032
# ABILENE       882
# ABINGDON      277
# ABINGTON      458
# Name: Bed Count, dtype: int32

# %%
total_hospitals_city = df.groupby('City')['Hospital Name'].count()
total_hospitals_city.head()
# Out:
# City
# ABBEVILLE    2
# ABERDEEN     4
# ABILENE      3
# ABINGDON     1
# ABINGTON     1
# Name: Hospital Name, dtype: int64

# %%
bed_hospital_ratio = total_beds_city / total_hospitals_city
bed_hospital_ratio.sort_values().head(10)
# Out:
# City
# HURON             20.0
# GRAND FORKS       20.0
# RIPON             20.0
# GRIFFIN           20.0
# BRYSON CITY       20.0
# GREENWICH         20.0
# PIERRE            20.0
# BURNSVILLE        20.0
# PHOENIXVILLE      20.0
# GUTHRIE CENTER    21.0
# dtype: float64

# %%
low_ratio_cities = bed_hospital_ratio[
    total_hospitals_city >= 3
]

low_ratio_cities.sort_values().head(10)
# Out:
# City
# FREDERICKSBURG     63.666667
# YOUNGSTOWN         73.000000
# PONCE              82.000000
# SHERIDAN           98.666667
# BLOOMINGTON       100.333333
# DURHAM            104.666667
# ALBUQUERQUE       110.400000
# GLENDALE          115.833333
# ERIE              120.333333
# FAYETTEVILLE      121.800000
# dtype: float64

# %%
valid_contacts = df.groupby('City')['Phone Number'] \
    .apply(lambda x: x.notnull().sum())

valid_contacts.head()
# Out:
# City
# ABBEVILLE    2
# ABERDEEN     4
# ABILENE      3
# ABINGDON     1
# ABINGTON     1
# Name: Phone Number, dtype: int64

# %%
valid_contacts.sort_values(ascending=False).head(10)
# Out:
# City
# CHICAGO         29
# HOUSTON         28
# LOS ANGELES     20
# PHILADELPHIA    19
# DALLAS          19
# COLUMBUS        18
# BALTIMORE       17
# WASHINGTON      16
# JACKSON         16
# PHOENIX         16
# Name: Phone Number, dtype: int64

# %%
valid_contacts.sort_values().head(10)
# Out:
# City
# LITHONIA            1
# NEW ROADS           1
# NEW ROCHELLE        1
# NEW SMYRNA BEACH    1
# NEW ULM             1
# NEWBERG             1
# NEWBURYPORT         1
# NEWCASTLE           1
# NEWPORT BEACH       1
# NIAGARA FALLS       1
# Name: Phone Number, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.hist(df['Bed Count'], bins=30)
plt.xlabel('Bed Count')
plt.ylabel('Number of Hospitals')
plt.title('Distribution of Hospital Bed Counts')
plt.show()

# %%
total_beds_city.sort_values(ascending=False).head(10)
# Out:
# City
# CHICAGO          8297
# HOUSTON          7929
# LOS ANGELES      5420
# PHILADELPHIA     5360
# DALLAS           5201
# SPRINGFIELD      4725
# PHOENIX          4528
# WASHINGTON       4523
# OKLAHOMA CITY    4281
# BALTIMORE        4224
# Name: Bed Count, dtype: int32

# %%
total_beds_city.sort_values().head(10)
# Out:
# City
# GRAND FORKS     20
# PHOENIXVILLE    20
# BRYSON CITY     20
# PIERRE          20
# RIPON           20
# HURON           20
# BURNSVILLE      20
# GRIFFIN         20
# GREENWICH       20
# LITITZ          21
# Name: Bed Count, dtype: int32

# %%
avg_beds_city = df.groupby('City')['Bed Count'].mean()
avg_beds_city.head()
# Out:
# City
# ABBEVILLE    392.5
# ABERDEEN     258.0
# ABILENE      294.0
# ABINGDON     277.0
# ABINGTON     458.0
# Name: Bed Count, dtype: float64

# %%
avg_beds_city.sort_values(ascending=False).head(10)
# Out:
# City
# KEYSER            499.0
# BALDWIN PARK      498.0
# WESTBROOK         498.0
# MCALLEN           498.0
# STURGEON BAY      498.0
# UPPER SANDUSKY    498.0
# ELKHORN           498.0
# EDMONDS           497.0
# KEALAKEKUA        497.0
# CLARE             496.0
# Name: Bed Count, dtype: float64

# %%
avg_beds_city.sort_values().head(10)
# Out:
# City
# HURON             20.0
# GRAND FORKS       20.0
# RIPON             20.0
# GRIFFIN           20.0
# BRYSON CITY       20.0
# GREENWICH         20.0
# PIERRE            20.0
# BURNSVILLE        20.0
# PHOENIXVILLE      20.0
# GUTHRIE CENTER    21.0
# Name: Bed Count, dtype: float64

# %%
beds_city = df.groupby('City')['Bed Count'].sum()
beds_city.head()
# Out:
# City
# ABBEVILLE     785
# ABERDEEN     1032
# ABILENE       882
# ABINGDON      277
# ABINGTON      458
# Name: Bed Count, dtype: int32

# %%
hospitals_city = df.groupby('City')['Hospital Name'].count()
hospitals_city.head()
# Out:
# City
# ABBEVILLE    2
# ABERDEEN     4
# ABILENE      3
# ABINGDON     1
# ABINGTON     1
# Name: Hospital Name, dtype: int64

# %%
bed_hospital_ratio = beds_city / hospitals_city
bed_hospital_ratio.sort_values().head(10)
# Out:
# City
# HURON             20.0
# GRAND FORKS       20.0
# RIPON             20.0
# GRIFFIN           20.0
# BRYSON CITY       20.0
# GREENWICH         20.0
# PIERRE            20.0
# BURNSVILLE        20.0
# PHOENIXVILLE      20.0
# GUTHRIE CENTER    21.0
# dtype: float64

# %%
critical_cities = bed_hospital_ratio[
    bed_hospital_ratio < bed_hospital_ratio.quantile(0.25)
]

critical_cities.sort_values().head(10)
# Out:
# City
# BRYSON CITY       20.0
# BURNSVILLE        20.0
# PIERRE            20.0
# PHOENIXVILLE      20.0
# HURON             20.0
# GRAND FORKS       20.0
# RIPON             20.0
# GRIFFIN           20.0
# GREENWICH         20.0
# GUTHRIE CENTER    21.0
# dtype: float64

# %%
df.groupby('Hospital Ownership')['Bed Count'].mean()
# Out:
# Hospital Ownership
# Government - Federal                           257.777778
# Government - Hospital District or Authority    265.249554
# Government - Local                             255.513514
# Government - State                             249.430769
# Physician                                      267.573529
# Proprietary                                    260.240000
# Tribal                                         248.222222
# Voluntary non-profit - Church                  254.492711
# Voluntary non-profit - Other                   253.316017
# Voluntary non-profit - Private                 260.237817
# Name: Bed Count, dtype: float64

# %%
df.groupby('Hospital Ownership')['Bed Count'].sum()
# Out:
# Hospital Ownership
# Government - Federal                            11600
# Government - Hospital District or Authority    148805
# Government - Local                             103994
# Government - State                              16213
# Physician                                       18195
# Proprietary                                    208192
# Tribal                                           2234
# Voluntary non-profit - Church                   87291
# Voluntary non-profit - Other                   117032
# Voluntary non-profit - Private                 534008
# Name: Bed Count, dtype: int32

# %%
beds_city.sort_values(ascending=False).head(10)
# Out:
# City
# CHICAGO          8297
# HOUSTON          7929
# LOS ANGELES      5420
# PHILADELPHIA     5360
# DALLAS           5201
# SPRINGFIELD      4725
# PHOENIX          4528
# WASHINGTON       4523
# OKLAHOMA CITY    4281
# BALTIMORE        4224
# Name: Bed Count, dtype: int32

# %%
overburdened = df.groupby('City').agg(
    Total_Hospitals=('Hospital Name', 'count'),
    Total_Beds=('Bed Count', 'sum')
).reset_index()

overburdened.head()
# Out:
#         City  Total_Hospitals  Total_Beds
# 0  ABBEVILLE                2         785
# 1   ABERDEEN                4        1032
# 2    ABILENE                3         882
# 3   ABINGDON                1         277
# 4   ABINGTON                1         458

# %%
print(df.columns)
# Out:
# Index(['Provider ID', 'Hospital Name', 'Address', 'City', 'State', 'ZIP Code',
#        'County Name', 'Phone Number', 'Hospital Type', 'Hospital Ownership',
#        'Emergency Services', 'Meets criteria for meaningful use of EHRs',
#        'Hospital overall rating', 'Hospital overall rating footnote',
#        'Mortality national comparison',
#        'Mortality national comparison footnote',
#        'Safety of care national comparison',
#        'Safety of care national comparison footnote',
#        'Readmission national comparison',
#        'Readmission national comparison footnote',
#        'Patient experience national comparison',
#        'Patient experience national comparison footnote',
#        'Effectiveness of care national comparison',
#        'Effectiveness of care national comparison footnote',
#        'Timeliness of care national comparison',
#        'Timeliness of care national comparison footnote',
# ...

# %%
df['Bed Count'] = pd.to_numeric(df['Bed Count'], errors='coerce')
df['Bed Count'].head()
# Out:
# 0    192
# 1     67
# 2    137
# 3    212
# 4    343
# Name: Bed Count, dtype: int32

# %%
def bed_category(beds):
    if beds < 50:
        return 'Small'
    elif beds <= 200:
        return 'Medium'
    else:
        return 'Large'

df['Bed Category'] = df['Bed Count'].apply(bed_category)

# %%
df[['Bed Count', 'Bed Category']].head()
# Out:
#    Bed Count Bed Category
# 0        192       Medium
# 1         67       Medium
# 2        137       Medium
# 3        212        Large
# 4        343        Large

# %%
bed_category_city = df.groupby(['City', 'Bed Category']) \
    .size() \
    .unstack(fill_value=0)

bed_category_city.head()
# Out:
# Bed Category  Large  Medium  Small
# City
# ABBEVILLE         2       0      0
# ABERDEEN          3       1      0
# ABILENE           2       0      1
# ABINGDON          1       0      0
# ABINGTON          1       0      0

# %%
bed_category_city.sort_values('Small', ascending=False).head(10)
# Out:
# Bed Category  Large  Medium  Small
# City
# GREENVILLE        9       2      3
# AUSTIN            7       1      3
# PONCE             0       1      2
# BIRMINGHAM        4       2      2
# JACKSON           8       6      2
# LANCASTER         4       2      2
# GREENSBURG        1       2      2
# HOUSTON          20       6      2
# MONTICELLO        4       2      2
# SUMNER            0       0      1

# %%
bed_category_city.sort_values('Medium', ascending=False).head(10)
# Out:
# Bed Category  Large  Medium  Small
# City
# COLUMBUS          8      10      0
# CHICAGO          20       9      0
# BALTIMORE         9       8      0
# LOS ANGELES      11       8      1
# PHILADELPHIA     12       6      1
# SPRINGFIELD      10       6      0
# HOUSTON          20       6      2
# ROCHESTER         4       6      0
# SAN JUAN          2       6      0
# JACKSONVILLE      6       6      0

# %%
df.groupby('City')['Hospital Name'].count() \
  .sort_values(ascending=False) \
  .head(10) \
  .plot(kind='bar')

plt.xlabel('City')
plt.ylabel('Number of Hospitals')
plt.title('Hospital Availability by City')
plt.show()

# %%
df.groupby('City')['Bed Count'].sum() \
  .sort_values(ascending=False) \
  .head(10) \
  .plot(kind='bar')

plt.xlabel('City')
plt.ylabel('Total Beds')
plt.title('Bed Distribution by City')
plt.show()

# %%
plt.hist(df['Bed Count'], bins=30)
plt.xlabel('Bed Count')
plt.ylabel('Number of Hospitals')
plt.title('Distribution of Hospital Bed Counts')
plt.show()

# %%
df['Bed Category'].value_counts().plot(kind='bar')
plt.xlabel('Bed Category')
plt.ylabel('Number of Hospitals')
plt.title('Distribution of Small, Medium, and Large Hospitals')
plt.show()

# %%
beds_city = df.groupby('City')['Bed Count'].sum()
hospitals_city = df.groupby('City')['Hospital Name'].count()

(beds_city / hospitals_city) \
    .sort_values() \
    .head(10) \
    .plot(kind='bar')

plt.xlabel('City')
plt.ylabel('Beds per Hospital')
plt.title('Cities with Lowest Bed-to-Hospital Ratio')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df['Patient experience national comparison footnote'] = df['Patient experience national comparison footnote'].replace('', 'Not Available')
df['Patient experience national comparison footnote'] = df['Patient experience national comparison footnote'].fillna('Not Available')

# %%
df.head(10)
# Out:
#    Provider ID                       Hospital Name  \
# 0        10005       MARSHALL MEDICAL CENTER SOUTH
# 1        10012      DEKALB REGIONAL MEDICAL CENTER
# 2        10032                    WEDOWEE HOSPITAL
# 3        10095                HALE COUNTY HOSPITAL
# 4        10131            CRESTWOOD MEDICAL CENTER
# 5        11304            CHOCTAW GENERAL HOSPITAL
# 6        20018  YUKON KUSKOKWIM DELTA REG HOSPITAL
# 7        21308      NORTON SOUND REGIONAL HOSPITAL
# 8        21309                  KANAKANAK HOSPITAL
# 9        21310              MANIILAQ HEALTH CENTER
#
#                                    Address        City State  ZIP Code  \
# 0               2505 U S HIGHWAY 431 NORTH        BOAZ    AL     35957
# 1                     200 MED CENTER DRIVE  FORT PAYNE    AL     35968
# 2                    209 NORTH MAIN STREET     WEDOWEE    AL     36278
# 3                         508 GREEN STREET  GREENSBORO    AL     36744
# ...

# %%
df['Effectiveness of care national comparison footnote'] = df['Effectiveness of care national comparison footnote'].replace('', 'Not Available')
df['Effectiveness of care national comparison footnote'] = df['Effectiveness of care national comparison footnote'].fillna('Not Available')

# %%
df.head(10)
# Out:
#    Provider ID                       Hospital Name  \
# 0        10005       MARSHALL MEDICAL CENTER SOUTH
# 1        10012      DEKALB REGIONAL MEDICAL CENTER
# 2        10032                    WEDOWEE HOSPITAL
# 3        10095                HALE COUNTY HOSPITAL
# 4        10131            CRESTWOOD MEDICAL CENTER
# 5        11304            CHOCTAW GENERAL HOSPITAL
# 6        20018  YUKON KUSKOKWIM DELTA REG HOSPITAL
# 7        21308      NORTON SOUND REGIONAL HOSPITAL
# 8        21309                  KANAKANAK HOSPITAL
# 9        21310              MANIILAQ HEALTH CENTER
#
#                                    Address        City State  ZIP Code  \
# 0               2505 U S HIGHWAY 431 NORTH        BOAZ    AL     35957
# 1                     200 MED CENTER DRIVE  FORT PAYNE    AL     35968
# 2                    209 NORTH MAIN STREET     WEDOWEE    AL     36278
# 3                         508 GREEN STREET  GREENSBORO    AL     36744
# ...

# %%
df['Timeliness of care national comparison footnote'] = df['Timeliness of care national comparison footnote'].replace('', 'Not Available')
df['Timeliness of care national comparison footnote'] = df['Timeliness of care national comparison footnote'].fillna('Not Available')

# %%
df.head(10)
# Out:
#    Provider ID                       Hospital Name  \
# 0        10005       MARSHALL MEDICAL CENTER SOUTH
# 1        10012      DEKALB REGIONAL MEDICAL CENTER
# 2        10032                    WEDOWEE HOSPITAL
# 3        10095                HALE COUNTY HOSPITAL
# 4        10131            CRESTWOOD MEDICAL CENTER
# 5        11304            CHOCTAW GENERAL HOSPITAL
# 6        20018  YUKON KUSKOKWIM DELTA REG HOSPITAL
# 7        21308      NORTON SOUND REGIONAL HOSPITAL
# 8        21309                  KANAKANAK HOSPITAL
# 9        21310              MANIILAQ HEALTH CENTER
#
#                                    Address        City State  ZIP Code  \
# 0               2505 U S HIGHWAY 431 NORTH        BOAZ    AL     35957
# 1                     200 MED CENTER DRIVE  FORT PAYNE    AL     35968
# 2                    209 NORTH MAIN STREET     WEDOWEE    AL     36278
# 3                         508 GREEN STREET  GREENSBORO    AL     36744
# ...

# %%
df['Efficient use of medical imaging national comparison footnote'] = df['Efficient use of medical imaging national comparison footnote'].replace('', 'Not Available')
df['Efficient use of medical imaging national comparison footnote'] = df['Effectiveness of care national comparison footnote'].fillna('Not Available')

# %%
df.head(10)
# Out:
#    Provider ID                       Hospital Name  \
# 0        10005       MARSHALL MEDICAL CENTER SOUTH
# 1        10012      DEKALB REGIONAL MEDICAL CENTER
# 2        10032                    WEDOWEE HOSPITAL
# 3        10095                HALE COUNTY HOSPITAL
# 4        10131            CRESTWOOD MEDICAL CENTER
# 5        11304            CHOCTAW GENERAL HOSPITAL
# 6        20018  YUKON KUSKOKWIM DELTA REG HOSPITAL
# 7        21308      NORTON SOUND REGIONAL HOSPITAL
# 8        21309                  KANAKANAK HOSPITAL
# 9        21310              MANIILAQ HEALTH CENTER
#
#                                    Address        City State  ZIP Code  \
# 0               2505 U S HIGHWAY 431 NORTH        BOAZ    AL     35957
# 1                     200 MED CENTER DRIVE  FORT PAYNE    AL     35968
# 2                    209 NORTH MAIN STREET     WEDOWEE    AL     36278
# 3                         508 GREEN STREET  GREENSBORO    AL     36744
# ...

# %%
df['Meets criteria for meaningful use of EHRs'] = df['Meets criteria for meaningful use of EHRs'].replace('', 'Not Available')
df['Meets criteria for meaningful use of EHRs'] = df['Meets criteria for meaningful use of EHRs'].fillna('Not Available')

# %%
df['Hospital overall rating footnote'] = df['Hospital overall rating footnote'].replace('', 'Not Available')
df['Hospital overall rating footnote'] = df['Hospital overall rating footnote'].fillna('Not Available')

# %%
df['Mortality national comparison footnote'] = df['Mortality national comparison footnote'].replace('', 'Not Available')
df['Mortality national comparison footnote'] = df['Mortality national comparison footnote'].fillna('Not Available')

# %%
df['Safety of care national comparison footnote'] = df['Safety of care national comparison footnote'].replace('', 'Not Available')
df['Safety of care national comparison footnote'] = df['Safety of care national comparison footnote'].fillna('Not Available')

# %%
df['Readmission national comparison footnote'] = df['Readmission national comparison footnote'].replace('', 'Not Available')
df['Readmission national comparison footnote'] = df['Readmission national comparison footnote'].fillna('Not Available')

# %%
df['Readmission national comparison footnote'] = df['Readmission national comparison footnote'].replace('', 'Not Available')
df['Readmission national comparison footnote'] = df['Readmission national comparison footnote'].fillna('Not Available')

# %%
df.head(10)
# Out:
#    Provider ID                       Hospital Name  \
# 0        10005       MARSHALL MEDICAL CENTER SOUTH
# 1        10012      DEKALB REGIONAL MEDICAL CENTER
# 2        10032                    WEDOWEE HOSPITAL
# 3        10095                HALE COUNTY HOSPITAL
# 4        10131            CRESTWOOD MEDICAL CENTER
# 5        11304            CHOCTAW GENERAL HOSPITAL
# 6        20018  YUKON KUSKOKWIM DELTA REG HOSPITAL
# 7        21308      NORTON SOUND REGIONAL HOSPITAL
# 8        21309                  KANAKANAK HOSPITAL
# 9        21310              MANIILAQ HEALTH CENTER
#
#                                    Address        City State  ZIP Code  \
# 0               2505 U S HIGHWAY 431 NORTH        BOAZ    AL     35957
# 1                     200 MED CENTER DRIVE  FORT PAYNE    AL     35968
# 2                    209 NORTH MAIN STREET     WEDOWEE    AL     36278
# 3                         508 GREEN STREET  GREENSBORO    AL     36744
# ...

# %%
df.to_csv('cleaned_hospital_data.csv', index=False)

# %%
df.columns
# Out:
# Index(['Provider ID', 'Hospital Name', 'Address', 'City', 'State', 'ZIP Code',
#        'County Name', 'Phone Number', 'Hospital Type', 'Hospital Ownership',
#        'Emergency Services', 'Meets criteria for meaningful use of EHRs',
#        'Hospital overall rating', 'Hospital overall rating footnote',
#        'Mortality national comparison',
#        'Mortality national comparison footnote',
#        'Safety of care national comparison',
#        'Safety of care national comparison footnote',
#        'Readmission national comparison',
#        'Readmission national comparison footnote',
#        'Patient experience national comparison',
#        'Patient experience national comparison footnote',
#        'Effectiveness of care national comparison',
#        'Effectiveness of care national comparison footnote',
#        'Timeliness of care national comparison',
#        'Timeliness of care national comparison footnote',
# ...

# %%
df.rename(columns={'Beds': 'Bed Count'}, inplace=True)

# %%
df.rename(columns={'No_of_Beds': 'Bed Count'}, inplace=True)

# %%
df['Bed Count'] = df['Bed Count'].fillna(df['Bed Count'].median())

# %%
df['Bed Count'] = pd.to_numeric(df['Bed Count'], errors='coerce')

# %%
def bed_category(beds):
    if beds <= 50:
        return 'Small'
    elif beds <= 200:
        return 'Medium'
    else:
        return 'Large'

df['Bed Category'] = df['Bed Count'].apply(bed_category)

# %%
df[['Bed Count', 'Bed Category']].head()
# Out:
#    Bed Count Bed Category
# 0        192       Medium
# 1         67       Medium
# 2        137       Medium
# 3        212        Large
# 4        343        Large

# %%
df.columns
# Out:
# Index(['Provider ID', 'Hospital Name', 'Address', 'City', 'State', 'ZIP Code',
#        'County Name', 'Phone Number', 'Hospital Type', 'Hospital Ownership',
#        'Emergency Services', 'Meets criteria for meaningful use of EHRs',
#        'Hospital overall rating', 'Hospital overall rating footnote',
#        'Mortality national comparison',
#        'Mortality national comparison footnote',
#        'Safety of care national comparison',
#        'Safety of care national comparison footnote',
#        'Readmission national comparison',
#        'Readmission national comparison footnote',
#        'Patient experience national comparison',
#        'Patient experience national comparison footnote',
#        'Effectiveness of care national comparison',
#        'Effectiveness of care national comparison footnote',
#        'Timeliness of care national comparison',
#        'Timeliness of care national comparison footnote',
# ...

# %%
df.to_csv("cleaned_hospital_data.csv", index=False)
print("Final cleaned dataset saved with Bed Count and Bed Category")
# Out:
# Final cleaned dataset saved with Bed Count and Bed Category
